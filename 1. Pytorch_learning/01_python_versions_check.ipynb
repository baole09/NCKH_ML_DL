# %%
# check library version numbers
# scipy
import scipy
print('scipy: %s' % scipy.__version__)
# numpy
import numpy
print('numpy: %s' % numpy.__version__)
# matplotlib
import matplotlib
print('matplotlib: %s' % matplotlib.__version__)
# pandas
import pandas
print('pandas: %s' % pandas.__version__)
# statsmodels
import statsmodels
print('statsmodels: %s' % statsmodels.__version__)
# scikit-learn
import sklearn
print('sklearn: %s' % sklearn.__version__)
# Out:
# scipy: 1.18.1
# numpy: 2.5.2
# matplotlib: 3.11.1
# pandas: 3.0.5
# statsmodels: 0.15.0
# sklearn: 1.9.0

# %%
cd NCKH_ML_DL
# Out:
# [WinError 2] The system cannot find the file specified: 'NCKH_ML_DL'
# C:\Users\baong\NCKH_ML_DL

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9C4A-9B46
#
#  Directory of C:\Users\baong\NCKH_ML_DL
#
# 08/30/2026  11:20 AM    <DIR>          .
# 08/30/2026  11:30 AM    <DIR>          ..
# 08/30/2026  11:20 AM    <DIR>          1. Pytorch_learning
# 08/30/2026  11:20 AM    <DIR>          2. Keras_learning
# 08/30/2026  11:20 AM               573 README.md
#                1 File(s)            573 bytes
#                4 Dir(s)  74,695,270,400 bytes free

# %%
# !dir notebooks
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9C4A-9B46
#
#  Directory of C:\Users\baong\NCKH_ML_DL
# File Not Found

# %%
# !dir "1. Pytorch_learning"
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9C4A-9B46
#
#  Directory of C:\Users\baong\NCKH_ML_DL\1. Pytorch_learning
#
# 08/30/2026  11:20 AM    <DIR>          .
# 08/30/2026  11:20 AM    <DIR>          ..
# 08/30/2026  11:20 AM                 2 .keep
# 08/30/2026  11:20 AM         3,127,568 pytorch_a1_setup_env.pdf
# 08/30/2026  11:20 AM             1,210 pytorch_a1_setup_env_code.zip
# 08/30/2026  11:20 AM           286,970 pytorch_p1_background.pdf
# 08/30/2026  11:20 AM            21,774 pytorch_p1_background_code.zip
# 08/30/2026  11:20 AM           470,288 pytorch_p2_mlp.pdf
# 08/30/2026  11:20 AM            91,410 pytorch_p2_mlp_code.zip
# 08/30/2026  11:20 AM           917,489 pytorch_p3_fine_tuning.pdf
# 08/30/2026  11:20 AM           158,654 pytorch_p3_fine_tuning_code.zip
# 08/30/2026  11:20 AM         1,042,296 pytorch_p4_advanced_models.pdf
# 08/30/2026  11:20 AM            78,360 pytorch_p4_advanced_models_code.zip
#               11 File(s)      6,196,021 bytes
#                2 Dir(s)  74,689,843,200 bytes free

# %%
import shutil
shutil.move("01_python_versions_check.ipynb", "1. Pytorch_learning/01_python_versions_check.ipynb")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\shutil.py:922, in move(src, dst, copy_function)
#     921 try:
# --> 922     os.rename(src, real_dst)
#     923 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: '01_python_versions_check.ipynb' -> '1. Pytorch_learning/01_python_versions_check.ipynb'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 2
#       1 import shutil
# ----> 2 shutil.move("01_python_versions_check.ipynb", "1. Pytorch_learning/01_python_versions_check.ipynb")
#
# File ~\anaconda3\Lib\shutil.py:942, in move(src, dst, copy_function)
#     940         rmtree(src)
#     941     else:
# --> 942         copy_function(src, real_dst)
#     943         os.unlink(src)
#     944 return real_dst
#
# File ~\anaconda3\Lib\shutil.py:514, in copy2(src, dst, follow_symlinks)
#     512     flags |= _winapi.COPY_FILE_COPY_SYMLINK
#     513 try:
# --> 514     _winapi.CopyFile2(src_, dst_, flags)
#     515     return dst
#     516 except OSError as exc:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
