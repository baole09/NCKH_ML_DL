# %%
# check deep learning version numbers
# pytorch
import torch
print('pytorch: %s' % torch.__version__)
# torchvision
import torchvision
print('torchvision: %s' % torchvision.__version__)
# Out:
# pytorch: 2.13.0+cpu
# torchvision: 0.28.0+cpu

# %%
# !git add 02_deep_versions_check.ipynb
# !git commit -m "checking deep learning versions "
# !git push origin main
# Out:
# warning: in the working copy of '1. Pytorch_learning/02_deep_versions_check.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 62f9588] checking deep learning versions
#  1 file changed, 38 insertions(+), 3 deletions(-)
# To https://github.com/baole09/NCKH_ML_DL.git
#    57982aa..62f9588  main -> main
